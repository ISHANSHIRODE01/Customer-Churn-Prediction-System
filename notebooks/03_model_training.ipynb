# %% [markdown]
# # 🏋️ 03_model_training.ipynb
#
# This notebook covers model training, optimization, and evaluation.

# %%
import sys
sys.path.append('..')
from src.train_model import train_churn_model
from src.evaluate_model import evaluate_performance

# Executing Training Script
train_churn_model('../data/raw/telco_customer_churn.csv', '../models/churn_model.pkl')

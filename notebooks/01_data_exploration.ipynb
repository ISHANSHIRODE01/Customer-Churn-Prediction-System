# %% [markdown]
# # 🧪 01_data_exploration.ipynb
#
# This notebook covers the initial EDA and statistical analysis.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('../data/raw/telco_customer_churn.csv')
df.head()

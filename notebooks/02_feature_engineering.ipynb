# %% [markdown]
# # 🛠️ 02_feature_engineering.ipynb
#
# This notebook covers building the scikit-learn preprocessing pipeline.

# %%
import sys
sys.path.append('..')
from src.feature_engineering import build_preprocessing_pipeline
import pandas as pd

df = pd.read_csv('../data/processed/cleaned_data.csv')
pipeline = build_preprocessing_pipeline(df)
print('Pipeline created.')
